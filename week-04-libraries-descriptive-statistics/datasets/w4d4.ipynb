# %%
import pandas as pd
import numpy as np

# %%
l = [32,25,25,65,98]
s = pd.Series(l)

# %%
s
# Out:
# 0    32
# 1    25
# 2    25
# 3    65
# 4    98
# dtype: int64

# %%
s
# Out:
# 0    32
# 1    25
# 2    25
# 3    65
# 4    98
# dtype: int64

# %%
s[3]
# Out:
# np.int64(65)

# %%
s[6]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 s[6]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# ...

# %%
data = {
    "name" : {"name " : "shakoor",'age ' : 20}
}

# %%
name = pd.Series(data)

# %%
name
# Out:
#           name
# name   shakoor
# age         20

# %%
df = pd.read_csv("Titanic_Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.to_string()
# Out:
# '     PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked\n0              1         0       3                                                             Braund, Mr. Owen Harris    male  22.00      1      0           A/5 21171    7.2500              NaN        S\n1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0            PC 17599   71.2833              C85        C\n2              3         1       3                                                              Heikkinen, Miss. Laina  female  26.00      0      0    STON/O2. 3101282    7.9250              NaN        S\n3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0              113803   53.1000
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
df.index = df['PassengerId']

# %%
df.head()
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 1                      1         0       3
# 2                      2         1       1
# 3                      3         1       3
# 4                      4         1       1
# 5                      5         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
df.loc[6]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 6, dtype: object

# %%
df
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 1                      1         0       3
# 2                      2         1       1
# 3                      3         1       3
# 4                      4         1       1
# 5                      5         0       3
# ...                  ...       ...     ...
# 887                  887         0       2
# 888                  888         1       1
# 889                  889         0       3
# 890                  890         1       1
# 891                  891         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
df['Survived']
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'] == 1
# Out:
# PassengerId
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 887    False
# 888     True
# 889    False
# 890     True
# 891    False
# Name: Survived, Length: 891, dtype: bool

# %%
df[df['Survived']==1]
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 2                      2         1       1
# 3                      3         1       3
# 4                      4         1       1
# 9                      9         1       3
# 10                    10         1       2
# ...                  ...       ...     ...
# 876                  876         1       3
# 880                  880         1       1
# 881                  881         1       2
# 888                  888         1       1
# 890                  890         1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# ...

# %%
df_sity = pd.read_csv(r"C:\Users\HP\Desktop\AI_project\week-04-libraries-descriptive-statistics\datasets\city_info.csv")

# %%
df_sity
# Out:
#         city                     province campus_type
# 0   Peshawar           Khyber Pakhtunkhwa        Main
# 1     Lahore                       Punjab        Main
# 2    Karachi                        Sindh        Main
# 3  Islamabad  Islamabad Capital Territory   Satellite
# 4     Quetta                  Balochistan   Satellite
# 5     Multan                       Punjab   Satellite

# %%
df_sity[df_sity["city"] == "Peshawar"]
# Out:
#        city            province campus_type
# 0  Peshawar  Khyber Pakhtunkhwa        Main

# %%
df
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 1                      1         0       3
# 2                      2         1       1
# 3                      3         1       3
# 4                      4         1       1
# 5                      5         0       3
# ...                  ...       ...     ...
# 887                  887         0       2
# 888                  888         1       1
# 889                  889         0       3
# 890                  890         1       1
# 891                  891         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
df["Fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 1                      1         0       3
# 2                      2         1       1
# 3                      3         1       3
# 4                      4         1       1
# 5                      5         0       3
# ...                  ...       ...     ...
# 887                  887         0       2
# 888                  888         1       1
# 889                  889         0       3
# 890                  890         1       1
# 891                  891         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
df[(df["Sex"] == 'female') & (df ["Age"] > 40)]
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 12                    12         1       1
# 16                    16         1       2
# 53                    53         1       1
# 133                  133         0       3
# 168                  168         0       3
# 178                  178         0       1
# 195                  195         1       1
# 196                  196         1       1
# 255                  255         0       3
# 260                  260         1       2
# 269                  269         1       1
# 273                  273         1       2
# 276                  276         1       1
# 277                  277         0       3
# 300                  300         1       1
# 338                  338         1       1
# 363                  363         0       3
# 367                  367         1       1
# 381                  381         1       1
# 433                  433         1       2
# ...

# %%
female_above = df[(df["Sex"] == 'female') & (df ["Age"] > 40)].shape

# %%
female_above
# Out:
# (48, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 122.8 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
stu = pd.read_csv(r'C:\Users\HP\Desktop\AI_project\week-04-libraries-descriptive-statistics\datasets\students.csv')

# %%
stu
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1103           S1103  Female  Peshawar    BSCS         4          5.5
# S1151           S1151  Female  Peshawar    BSSE         6          3.5
# S1067           S1067    Male    Lahore    BSSE         7          1.4
# S1025           S1025    Male  Peshawar    BSEE         2          7.9
# S1175           S1175    Male   Karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship
# student_id
# ...

# %%
stu
# Out:
#     student_id  gender      city program  semester  study_hours  attendance  \
# 0        S1099  Female    Quetta     BBA         1          8.1        87.5
# 1        S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2        S1131  Female    Lahore     BBA         7          4.0        96.9
# 3        S1024  Female  PESHAWAR    BSCS         3          2.5       100.0
# 4        S1065    Male    Quetta    BSSE         4          7.7        87.8
# ..         ...     ...       ...     ...       ...          ...         ...
# 179      S1103  Female  Peshawar    BSCS         4          5.5        68.6
# 180      S1151  Female  Peshawar    BSSE         6          3.5        70.1
# 181      S1067    Male    Lahore    BSSE         7          1.4        82.0
# 182      S1025    Male  Peshawar    BSEE         2          7.9        97.8
# 183      S1175    Male   Karachi    BSCS         1          6.3        75.5
#
#      prev_gpa  final_marks  scholarship
# ...

# %%
stu[stu["scholarship"] == 1]
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1141           S1141    Male    Lahore    BSEE         5          3.2
# S1168           S1168    Male   KARACHI    BSSE         3          7.8
# S1045           S1045  Female    Multan    BSEE         7          3.2
# S1129           S1129  Female  Peshawar     BBA         8          3.6
# S1166           S1166  Female    Multan    BSEE         7          7.4
# ...               ...     ...       ...     ...       ...          ...
# S1136           S1136  Female    Lahore     BBA         5          5.9
# S1042           S1042  Female   Karachi    BSSE         3          4.4
# S1110           S1110    Male    Quetta     BBA         4          1.0
# S1072           S1072  Female    Lahore    BSSE         4          4.8
# S1103           S1103  Female  Peshawar    BSCS         4          5.5
#
#             attendance  prev_gpa  final_marks  scholarship
# student_id
# ...

# %%
stu[stu["attendance"] >= 75]
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1023           S1023  Female  Peshawar     BBA         2          5.6
# S1142           S1142  Female    Lahore    BSEE         8          4.6
# S1067           S1067    Male    Lahore    BSSE         7          1.4
# S1025           S1025    Male  Peshawar    BSEE         2          7.9
# S1175           S1175    Male   Karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship
# student_id
# ...

# %%
stu['city']
# Out:
# 0        Quetta
# 1       Karachi
# 2        Lahore
# 3      PESHAWAR
# 4        Quetta
#          ...
# 179    Peshawar
# 180    Peshawar
# 181      Lahore
# 182    Peshawar
# 183     Karachi
# Name: city, Length: 184, dtype: str

# %%
stu.iloc[6]
# Out:
# student_id        S1032
# gender             Male
# city           Peshawar
# program             BBA
# semester              2
# study_hours         0.5
# attendance         81.3
# prev_gpa           2.17
# final_marks        48.3
# scholarship           0
# Name: 6, dtype: object

# %%
stu
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1103           S1103  Female  Peshawar    BSCS         4          5.5
# S1151           S1151  Female  Peshawar    BSSE         6          3.5
# S1067           S1067    Male    Lahore    BSSE         7          1.4
# S1025           S1025    Male  Peshawar    BSEE         2          7.9
# S1175           S1175    Male   Karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship
# student_id
# ...

# %%
st.head()
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
#
#             attendance  prev_gpa  final_marks  scholarship
# student_id
# S1099             87.5      1.91         68.5            0
# S1179             77.4       NaN         54.4            0
# S1131             96.9       NaN         68.7            0
# S1024            100.0      2.84         56.8            0
# S1065             87.8       NaN         68.8            0

# %%
stu [ stu ['city'] == 'Peshawar']
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1032           S1032    Male  Peshawar     BBA         2          0.5
# S1074           S1074    Male  Peshawar    BSCS         3          2.7
# S1121           S1121  Female  Peshawar    BSCS         4         30.0
# S1129           S1129  Female  Peshawar     BBA         8          3.6
# S1091           S1091  Female  Peshawar    BSEE         6          6.6
# S1080           S1080  Female  Peshawar    BSEE         5          8.1
# S1088           S1088    Male  Peshawar    BSCS         8          6.1
# S1169           S1169  Female  Peshawar    BSCS         8          8.0
# S1078           S1078    Male  Peshawar    BSSE         4         14.1
# S1036           S1036    Male  Peshawar    BSSE         8          8.3
# S1102           S1102    Male  Peshawar    BSEE         6          5.0
# S1128           S1128    Male  Peshawar     BBA         3          6.1
# ...

# %%
pesh =stu [ stu ['city'] == 'Peshawar']
pesh.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 55 entries, S1032 to S1025
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   55 non-null     str
#  1   gender       55 non-null     str
#  2   city         55 non-null     str
#  3   program      55 non-null     str
#  4   semester     55 non-null     int64
#  5   study_hours  54 non-null     float64
#  6   attendance   51 non-null     float64
#  7   prev_gpa     53 non-null     float64
#  8   final_marks  55 non-null     float64
#  9   scholarship  55 non-null     int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 4.7+ KB

# %%
pesh.describe()
# Out:
#         semester  study_hours  attendance   prev_gpa  final_marks  scholarship
# count  55.000000    54.000000   51.000000  53.000000    55.000000    55.000000
# mean    4.781818     7.314815   82.905882   2.898868    67.081818     0.309091
# std     2.322920     5.527680   10.992678   0.601740    12.108171     0.466378
# min     1.000000     0.500000   55.800000   1.370000    38.100000     0.000000
# 25%     3.000000     3.675000   76.550000   2.420000    59.700000     0.000000
# 50%     5.000000     6.350000   82.000000   2.910000    65.900000     0.000000
# 75%     7.000000     8.375000   90.600000   3.300000    74.550000     1.000000
# max     8.000000    30.000000  100.000000   3.960000    92.400000     1.000000

# %%
male =stu [ (stu ['city'] == 'Peshawar') & ( stu['gender'] == "Male")]
male
# Out:
#            student_id gender      city program  semester  study_hours  \
# student_id
# S1032           S1032   Male  Peshawar     BBA         2          0.5
# S1074           S1074   Male  Peshawar    BSCS         3          2.7
# S1088           S1088   Male  Peshawar    BSCS         8          6.1
# S1078           S1078   Male  Peshawar    BSSE         4         14.1
# S1036           S1036   Male  Peshawar    BSSE         8          8.3
# S1102           S1102   Male  Peshawar    BSEE         6          5.0
# S1128           S1128   Male  Peshawar     BBA         3          6.1
# S1037           S1037   Male  Peshawar    BSCS         5          8.3
# S1113           S1113   Male  Peshawar    BSCS         6          8.4
# S1028           S1028   Male  Peshawar    BSCS         8          6.3
# S1049           S1049   Male  Peshawar    BSEE         6          2.7
# S1046           S1046   Male  Peshawar    BSCS         7          0.5
# ...

# %%
lahore =stu [ (stu ['city'] == 'Lahore') ]
lahore
# Out:
#            student_id  gender    city program  semester  study_hours  \
# student_id
# S1131           S1131  Female  Lahore     BBA         7          4.0
# S1141           S1141    Male  Lahore    BSEE         5          3.2
# S1174           S1174    Male  Lahore    BSCS         6          NaN
# S1051           S1051    Male  Lahore    BSSE         6          3.0
# S1130           S1130    Male  Lahore    BSSE         5          1.9
# S1040           S1040    Male  Lahore    BSCS         1          4.5
# S1095           S1095  Female  Lahore    BSCS         3          1.1
# S1126           S1126    Male  Lahore     BBA         5          8.0
# S1125           S1125    Male  Lahore     BBA         8          7.7
# S1082           S1082  Female  Lahore    BSSE         7          2.1
# S1041           S1041  Female  Lahore    BSEE         1         10.8
# S1003           S1003  Female  Lahore    BSCS         5          7.5
# ...

# %%
lahore.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 29 entries, S1131 to S1067
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   29 non-null     str
#  1   gender       29 non-null     str
#  2   city         29 non-null     str
#  3   program      29 non-null     str
#  4   semester     29 non-null     int64
#  5   study_hours  28 non-null     float64
#  6   attendance   26 non-null     float64
#  7   prev_gpa     27 non-null     float64
#  8   final_marks  29 non-null     float64
#  9   scholarship  29 non-null     int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 2.5+ KB

# %%
lahore.describe()
# Out:
#         semester  study_hours  attendance   prev_gpa  final_marks  scholarship
# count  29.000000    28.000000   26.000000  27.000000    29.000000    29.000000
# mean    4.896552     5.832143   80.992308   2.804444    63.565517     0.551724
# std     2.110261     3.668288   12.119370   0.580035    11.924832     0.506120
# min     1.000000     1.000000   56.700000   1.660000    32.100000     0.000000
# 25%     4.000000     2.925000   71.400000   2.545000    59.500000     0.000000
# 50%     5.000000     5.350000   84.450000   2.930000    65.300000     1.000000
# 75%     7.000000     7.700000   89.400000   3.175000    70.800000     1.000000
# max     8.000000    14.100000   99.800000   3.890000    83.000000     1.000000

# %%
schl =stu [ (stu ['city'] == 'Peshawar') & ( stu['scholarship'] == 1)]

# %%
schl
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1129           S1129  Female  Peshawar     BBA         8          3.6
# S1091           S1091  Female  Peshawar    BSEE         6          6.6
# S1080           S1080  Female  Peshawar    BSEE         5          8.1
# S1088           S1088    Male  Peshawar    BSCS         8          6.1
# S1078           S1078    Male  Peshawar    BSSE         4         14.1
# S1102           S1102    Male  Peshawar    BSEE         6          5.0
# S1049           S1049    Male  Peshawar    BSEE         6          2.7
# S1062           S1062    Male  Peshawar    BSCS         8          NaN
# S1026           S1026    Male  Peshawar    BSSE         2          7.2
# S1154           S1154    Male  Peshawar    BSCS         6         15.6
# S1111           S1111    Male  Peshawar     BBA         3          6.5
# S1090           S1090    Male  Peshawar    BSCS         6          6.4
# ...

# %%
stu['city'].unique()
# Out:
# <StringArray>
# [   'Quetta',   'Karachi',    'Lahore',  'PESHAWAR',  'Peshawar',   'KARACHI',
#     'Multan', 'Islamabad']
# Length: 8, dtype: str

# %%
attendacee ="fail"  if  stu['attendance'] < 75  else "pass"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 attendacee ="fail"  if  stu['attendance'] < 75 else "pass"
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:1513, in NDFrame.__bool__(self)
#    1511     @final
#    1512     def __bool__(self) -> NoReturn:
# -> 1513         raise ValueError(
#    1514             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1515             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1516         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
attendance_short = stu ["attendance"] < 75

# %%
# Out:
# student_id
# S1099    False
# S1179    False
# S1131    False
# S1024    False
# S1065    False
#          ...
# S1103     True
# S1151     True
# S1067    False
# S1025    False
# S1175    False
# Name: attendance, Length: 184, dtype: bool

# %%
stu['Attendance'] = attendance_short

# %%
stu
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1103           S1103  Female  Peshawar    BSCS         4          5.5
# S1151           S1151  Female  Peshawar    BSSE         6          3.5
# S1067           S1067    Male    Lahore    BSSE         7          1.4
# S1025           S1025    Male  Peshawar    BSEE         2          7.9
# S1175           S1175    Male   Karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship  Attendance
# student_id
# ...

# %%
 stu["Status"] = np.where(stu["attendance"] < 75 , "fail","pass")

# %%
stu
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1103           S1103  Female  Peshawar    BSCS         4          5.5
# S1151           S1151  Female  Peshawar    BSSE         6          3.5
# S1067           S1067    Male    Lahore    BSSE         7          1.4
# S1025           S1025    Male  Peshawar    BSEE         2          7.9
# S1175           S1175    Male   Karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship  Attendance Status
# student_id
# ...

# %%
stu
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    Quetta     BBA         1          8.1
# S1179           S1179  Female   Karachi    BSSE         7          5.2
# S1131           S1131  Female    Lahore     BBA         7          4.0
# S1024           S1024  Female  PESHAWAR    BSCS         3          2.5
# S1065           S1065    Male    Quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1103           S1103  Female  Peshawar    BSCS         4          5.5
# S1151           S1151  Female  Peshawar    BSSE         6          3.5
# S1067           S1067    Male    Lahore    BSSE         7          1.4
# S1025           S1025    Male  Peshawar    BSEE         2          7.9
# S1175           S1175    Male   Karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship  Attendance Status
# student_id
# ...

# %%
def low (s):
    return s.lower()

# %%
 stu['city']=stu ['city '] =stu['city'].apply(low)

# %%
stu
# Out:
#            student_id  gender      city program  semester  study_hours  \
# student_id
# S1099           S1099  Female    quetta     BBA         1          8.1
# S1179           S1179  Female   karachi    BSSE         7          5.2
# S1131           S1131  Female    lahore     BBA         7          4.0
# S1024           S1024  Female  peshawar    BSCS         3          2.5
# S1065           S1065    Male    quetta    BSSE         4          7.7
# ...               ...     ...       ...     ...       ...          ...
# S1103           S1103  Female  peshawar    BSCS         4          5.5
# S1151           S1151  Female  peshawar    BSSE         6          3.5
# S1067           S1067    Male    lahore    BSSE         7          1.4
# S1025           S1025    Male  peshawar    BSEE         2          7.9
# S1175           S1175    Male   karachi    BSCS         1          6.3
#
#             attendance  prev_gpa  final_marks  scholarship  Attendance Status  \
# student_id
# ...
