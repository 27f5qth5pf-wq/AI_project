# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\AI_project\week-04-libraries-descriptive-statistics\datasets\students.csv")

# %%
df
# Out:
#     student_id  gender      city program  semester  study_hours  attendance  \
# 0        S1099  Female    Quetta     BBA         1          8.1        87.5
# 1        S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2        S1131  Female    Lahore     BBA         7          4.0        96.9
# 3        S1024  Female  PESHAWAR    BSCS         3          2.5       100.0
# 4        S1065    Male    Quetta    BSSE         4          7.7        87.8
# ..         ...     ...       ...     ...       ...          ...         ...
# 179      S1103  Female  Peshawar    BSCS         4          5.5        68.6
# 180      S1151  Female  Peshawar    BSSE         6          3.5        70.1
# 181      S1067    Male    Lahore    BSSE         7          1.4        82.0
# 182      S1025    Male  Peshawar    BSEE         2          7.9        97.8
# 183      S1175    Male   Karachi    BSCS         1          6.3        75.5
#
#      prev_gpa  final_marks  scholarship
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   184 non-null    str
#  1   gender       184 non-null    str
#  2   city         184 non-null    str
#  3   program      184 non-null    str
#  4   semester     184 non-null    int64
#  5   study_hours  179 non-null    float64
#  6   attendance   168 non-null    float64
#  7   prev_gpa     174 non-null    float64
#  8   final_marks  184 non-null    float64
#  9   scholarship  184 non-null    int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 14.5 KB

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  PESHAWAR    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0      1.91         68.5            0
# 1       NaN         54.4            0
# 2       NaN         68.7            0
# 3      2.84         56.8            0
# 4       NaN         68.8            0

# %%
df.shape
# Out:
# (184, 10)

# %%
for col in ['study_hours','attendance','prev_gpa']:
    df[col] = df[col].fillna(df[col].mean(),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22540\682817350.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col] = df[col].fillna(df[col].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id     0
# gender         0
# city           0
# program        0
# semester       0
# study_hours    0
# attendance     0
# prev_gpa       0
# final_marks    0
# scholarship    0
# dtype: int64

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'male', 'female']
# Length: 4, dtype: str

# %%
df['gender'] = df['gender'].str.title()

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df['city'].unique()
# Out:
# <StringArray>
# [   'Quetta',   'Karachi',    'Lahore',  'PESHAWAR',  'Peshawar',   'KARACHI',
#     'Multan', 'Islamabad']
# Length: 8, dtype: str

# %%
df['city']=df['city'].str.title()

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
sns.regplot(data= df , x = "attendance" , y = 'final_marks')
# Out:
# <Axes: xlabel='attendance', ylabel='final_marks'>

# %%
df[["attendance" , 'final_marks']].corr()
# Out:
#              attendance  final_marks
# attendance     1.000000     0.308842
# final_marks    0.308842     1.000000

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'city', 'program', 'semester', 'study_hours',
#        'attendance', 'prev_gpa', 'final_marks', 'scholarship'],
#       dtype='str')

# %%
sns.regplot(data = df , x = 'study_hours' , y =  'final_marks')
# Out:
# <Axes: xlabel='study_hours', ylabel='final_marks'>

# %%
df[['study_hours' ,   'final_marks']] . corr()
# Out:
#              study_hours  final_marks
# study_hours     1.000000     0.655732
# final_marks     0.655732     1.000000

# %%
sns.histplot(data = df , x ='study_hours')
plt.title('Histogarm of  study_hours')
plt.show()

# %%
sns.histplot(data = df , x ='study_hours' ,kde=True)
plt.title('Histogarm of  study_hours')
plt.show()

# %%
tick = np.linspace(df['study_hours'].min(), df['study_hours'].max(), 11)
sns.histplot(data = df , x ='study_hours' , kde = True , bins= 10)
plt.xticks(tick)
plt.title('Histogarm of  study_hours')
plt.show()

# %%
sns.boxplot(data =df , x= 'final_marks' , color= 'r')
plt.title('Final marks')
# Out:
# Text(0.5, 1.0, 'Final marks')

# %%
sns.boxplot(data =df , x= 'final_marks' , color= 'r')
plt.axvline(np.percentile(df['final_marks'],25))
plt.title('box plot for Final marks')
# Out:
# Text(0.5, 1.0, 'box plot for Final marks')

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
sns.countplot(data =df , x = 'gender' ,width=0.1)
plt.title('no of female and male')
plt.show()

# %%
sns.countplot(data = df , x = 'program' , width= 0.3 ,)
plt.grid()

# %%
sns.barplot(data = df , x ='city' ,  y = 'final_marks', width= 0.5)
# Out:
# <Axes: xlabel='city', ylabel='final_marks'>

# %%
sns.violinplot(data = df , x = 'final_marks')
# Out:
# <Axes: xlabel='final_marks'>

# %%
sns.violinplot(data = df , x = 'city' , color = "r")
# Out:
# <Axes: xlabel='city'>

# %%
sns.boxplot(data = df , x = 'program', y =  'final_marks' )
# Out:
# <Axes: xlabel='program', ylabel='final_marks'>

# %%
sns.scatterplot(data = df  , x  = 'study_hours'  , y = 'final_marks')
# Out:
# <Axes: xlabel='study_hours', ylabel='final_marks'>

# %%
sns.regplot(data = df  , x  = 'study_hours'  , y = 'final_marks' , scatter_kws={'alpha':0.8 } , line_kws={'color':'red'})

plt.legend()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22540\2747119015.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.regplot(data = df  , x  = 'study_hours'  , y = 'final_marks' ,label='marks', scatter_kws={'alpha':0.8 } , line_kws={'color':'red' , 'label':'Reg line'})

plt.legend()

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
sns.regplot(data = df  , x  = 'attendance'  , y = 'final_marks' ,label='marks', scatter_kws={'alpha':0.8 } , line_kws={'color':'red' , 'label':'Reg line'})

plt.legend()

# %%
sns.pairplot(data = df[['study_hours' , 'attendance' , 'prev_gpa','final_marks']])

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
x = df[['study_hours' , 'prev_gpa' , 'attendance']]
x.head()
# Out:
#    study_hours  prev_gpa  attendance
# 0          8.1  1.910000        87.5
# 1          5.2  2.839655        77.4
# 2          4.0  2.839655        96.9
# 3          2.5  2.840000       100.0
# 4          7.7  2.839655        87.8

# %%
arr= np.array([
    [40,60,30],
    [60,80,20],
    [50,90,100]
    ])

# %%
sns.heatmap(arr, vmin = 0, vmax= 100)
# Out:
# <Axes: >

# %%
df [["attendance" , "study_hours" , "prev_gpa" , "final_marks"]]
# Out:
#      attendance  study_hours  prev_gpa  final_marks
# 0          87.5          8.1  1.910000         68.5
# 1          77.4          5.2  2.839655         54.4
# 2          96.9          4.0  2.839655         68.7
# 3         100.0          2.5  2.840000         56.8
# 4          87.8          7.7  2.839655         68.8
# ..          ...          ...       ...          ...
# 179        68.6          5.5  3.730000         56.0
# 180        70.1          3.5  2.370000         63.5
# 181        82.0          1.4  2.140000         65.3
# 182        97.8          7.9  2.350000         71.5
# 183        75.5          6.3  2.040000         57.8
#
# [184 rows x 4 columns]

# %%
cor = df [["attendance" , "study_hours" , "prev_gpa" , "final_marks"]].corr()

# %%
cor
# Out:
#              attendance  study_hours  prev_gpa  final_marks
# attendance     1.000000    -0.031473  0.007365     0.308842
# study_hours   -0.031473     1.000000  0.062176     0.655732
# prev_gpa       0.007365     0.062176  1.000000     0.278158
# final_marks    0.308842     0.655732  0.278158     1.000000

# %%
sns.heatmap(cor , vmin = -1 , vmax= 1  , cmap = 'coolwarm' , annot = True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   student_id  gender      city program  semester  study_hours  attendance  \
# 0      S1099  Female    Quetta     BBA         1          8.1        87.5
# 1      S1179  Female   Karachi    BSSE         7          5.2        77.4
# 2      S1131  Female    Lahore     BBA         7          4.0        96.9
# 3      S1024  Female  Peshawar    BSCS         3          2.5       100.0
# 4      S1065    Male    Quetta    BSSE         4          7.7        87.8
#
#    prev_gpa  final_marks  scholarship
# 0  1.910000         68.5            0
# 1  2.839655         54.4            0
# 2  2.839655         68.7            0
# 3  2.840000         56.8            0
# 4  2.839655         68.8            0

# %%
fig , ax = plt.subplots(1,2, figsize=(10,4))

ax[0].scatter(df['study_hours'], df['final_marks'])
ax[0].set_title("study hours vs final marks")
ax[0].set_xlebal("study hours")
ax[0].set_ylebal("study final marks")


ax[1].scatter(df['attendance'], df['final_marks'])
ax[1].set_title("attendance vs final marks")
ax[1].set_lebal("attendance")
ax[1].set_ylebal("study final marks")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[233], line 4
#       1 fig , ax = plt.subplots(1,2, figsize=(10,4))
#       2 ax[0].scatter(df['study_hours'], df['final_marks'])
#       3 ax[0].set_title("study hours vs final marks")
# ----> 4 ax[0].set_xlebal("study hours")
#       5 ax[0].set_ylebal("study final marks")
#       6
#       7
#
# AttributeError: 'Axes' object has no attribute 'set_xlebal'
