# %%
salaries = [
    42500, 45000, 47500, 48000, 49500,
    50000, 51000, 52000, 52500, 53000,
    54000, 54500, 55000, 56000, 57000,
    58000, 58500, 59000, 60000, 61000,
    62000, 63000, 64000, 65000, 66000,
    67500, 69000, 71000,
    180000, 250000 
]

# %%
import numpy as np
import scipy as stats

# %%
salaries_arr = np.array(salaries)

# %%
salaries_arr
# Out:
# array([ 42500,  45000,  47500,  48000,  49500,  50000,  51000,  52000,
#         52500,  53000,  54000,  54500,  55000,  56000,  57000,  58000,
#         58500,  59000,  60000,  61000,  62000,  63000,  64000,  65000,
#         66000,  67500,  69000,  71000, 180000, 250000])

# %%
salaries_arr.shape
# Out:
# (30,)

# %%
salaries_arr.size
# Out:
# 30

# %%
salaries_arr.ndim
# Out:
# 1

# %%
salaries_arr.itemsize
# Out:
# 4

# %%
salaries_arr.dtype
# Out:
# dtype('int32')

# %%
salaries_arr.mean()
# Out:
# 67383.33333333333

# %%
np.median(salaries_arr)
# Out:
# 57500.0

# %%
np.max(salaries_arr)
# Out:
# 250000

# %%
salaries_arr.max()
# Out:
# 250000

# %%
salaries_arr.min()
# Out:
# 42500

# %%
np.sort(salaries_arr)
# Out:
# array([ 42500,  45000,  47500,  48000,  49500,  50000,  51000,  52000,
#         52500,  53000,  54000,  54500,  55000,  56000,  57000,  58000,
#         58500,  59000,  60000,  61000,  62000,  63000,  64000,  65000,
#         66000,  67500,  69000,  71000, 180000, 250000])

# %%
salaries_arr
# Out:
# array([ 42500,  45000,  47500,  48000,  49500,  50000,  51000,  52000,
#         52500,  53000,  54000,  54500,  55000,  56000,  57000,  58000,
#         58500,  59000,  60000,  61000,  62000,  63000,  64000,  65000,
#         66000,  67500,  69000,  71000, 180000, 250000])

# %%
salaries_arr.sort()

# %%
salaries_arr
# Out:
# array([ 42500,  45000,  47500,  48000,  49500,  50000,  51000,  52000,
#         52500,  53000,  54000,  54500,  55000,  56000,  57000,  58000,
#         58500,  59000,  60000,  61000,  62000,  63000,  64000,  65000,
#         66000,  67500,  69000,  71000, 180000, 250000])

# %%
sorted(salaries_arr, reverse=True)
# Out:
# [250000,
#  180000,
#  71000,
#  69000,
#  67500,
#  66000,
#  65000,
#  64000,
#  63000,
#  62000,
#  61000,
#  60000,
#  59000,
#  58500,
#  58000,
#  57000,
#  56000,
#  55000,
#  54500,
#  54000,
#  53000,
#  52500,
#  52000,
#  51000,
#  50000,
#  49500,
#  48000,
#  47500,
#  45000,
#  42500]

# %%
salaries_arr.argmax()
# Out:
# 29

# %%
salaries_arr.size
# Out:
# 30

# %%
salaries_arr.argmin()
# Out:
# 0

# %%
salaries_arr
# Out:
# array([ 42500,  45000,  47500,  48000,  49500,  50000,  51000,  52000,
#         52500,  53000,  54000,  54500,  55000,  56000,  57000,  58000,
#         58500,  59000,  60000,  61000,  62000,  63000,  64000,  65000,
#         66000,  67500,  69000,  71000, 180000, 250000])

# %%
import numpy as np

# %%
rand_arr = np.random.randint(0, 10000, size=(5,6))

# %%
rand_arr
# Out:
# array([[7333, 6197, 8792, 8528, 6598, 9009],
#        [8183, 6566, 2349,  491, 5033, 8738],
#        [3606, 6173, 9965, 9404, 4993, 3302],
#        [6002, 6719, 5581, 3517, 4997, 2760],
#        [1114, 4254,  708, 7676, 9353,  553]])

# %%
rand_arr.max(0)
# Out:
# array([8183, 6719, 9965, 9404, 9353, 9009])

# %%
rand_arr.max(1)
# Out:
# array([9009, 8738, 9965, 6719, 9353])

# %%
rand_arr[0],  + rand_arr[1] + rand_arr[2]

# %%
rand_arr.min(0)
# Out:
# array([1114, 4254,  708,  491, 4993,  553])

# %%
rand_arr.min(1)
# Out:
# array([6197,  491, 3302, 2760,  553])

# %%
rand_arr.mean(0)
# Out:
# array([5247.6, 5981.8, 5479. , 5923.2, 6194.8, 4872.4])

# %%
rand_arr.shape
# Out:
# (5, 6)

# %%
rand_arr.mean(1)
# Out:
# array([7742.83333333, 5226.66666667, 6240.5       , 4929.33333333,
#        3943.        ])

# %%
rand_arr.mean()
# Out:
# 5616.466666666666

# %%
arr1 = np.array([
    [32, 453],
    [53, 23]
])


arr2 = np.array([
    [54, 23],
    [86, 23]
])

# %%
np.concatenate((arr1, arr2))
# Out:
# array([[ 32, 453],
#        [ 53,  23],
#        [ 54,  23],
#        [ 86,  23]])

# %%
np.concatenate((arr1, arr2), 1)
# Out:
# array([[ 32, 453,  54,  23],
#        [ 53,  23,  86,  23]])

# %%
arr1
# Out:
# array([[ 32, 453],
#        [ 53,  23]])

# %%
np.insert(arr1, 0, [55, 67])
# Out:
# array([ 55,  67,  32, 453,  53,  23])

# %% [markdown]
# ### Boolean Indixing

# %%
import numpy as np

# %%
arr = np.random.randint(0, 100, size=(3, 3))

# %%
arr
# Out:
# array([[ 5, 39, 22],
#        [51, 88, 13],
#        [55, 39,  4]])

# %%
arr >= 50
# Out:
# array([[False, False, False],
#        [ True,  True, False],
#        [ True, False, False]])

# %%
arr_1d = np.array([32, 43])

# %%
l = [True, False]

arr_1d[l]
# Out:
# array([32])

# %%
mask = arr >= 50

# %%
mask
# Out:
# array([[False, False, False],
#        [ True,  True, False],
#        [ True, False, False]])

# %%
arr
# Out:
# array([[ 5, 39, 22],
#        [51, 88, 13],
#        [55, 39,  4]])

# %%
arr[mask]
# Out:
# array([51, 88, 55])

# %%
arr[arr>=50]
# Out:
# array([51, 88, 55])

# %%
import matplotlib.pyplot as plt

# %%
image = plt.imread(r"images\lena.jfif")

# %%
image
# Out:
# array([[[229, 134, 116],
#         [229, 134, 116],
#         [230, 135, 115],
#         ...,
#         [192, 105, 114],
#         [222, 135, 144],
#         [223, 136, 145]],
#
#        [[228, 133, 115],
#         [228, 133, 115],
#         [229, 134, 114],
#         ...,
#         [208, 122, 135],
#         [203, 117, 130],
#         [186, 100, 113]],
#
#        [[227, 132, 112],
#         [227, 132, 112],
#         [227, 132, 112],
#         ...,
#         [146,  61,  82],
#         [115,  30,  51],
#         [ 93,   8,  29]],
#
#        ...,
#
#        [[ 95,  19,  58],
#         [100,  30,  66],
#         [104,  43,  74],
#         ...,
#         [111,  33,  57],
#         [117,  39,  63],
#         [122,  44,  66]],
#
#        [[ 94,  18,  57],
#         [ 95,  25,  61],
#         [ 96,  35,  66],
#         ...,
#         [116,  38,  62],
#         [134,  55,  77],
#         [145,  66,  87]],
#
#        [[ 98,  22,  61],
#         [ 94,  24,  60],
#         [ 90,  29,  60],
# ...

# %%
image.shape
# Out:
# (148, 148, 3)

# %%
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 147.5, 147.5, -0.5)

# %%
image1 = image.copy()

# %%
image1[:, :, 0] = 0

# %%
plt.imshow(image1)
plt.axis('off')
# Out:
# (-0.5, 147.5, 147.5, -0.5)

# %%
r = image[:, :, 0].copy()
g = image[:, :, 1].copy()
b = image[:, :, 2].copy()

# %%
print(r.shape)
print(g.shape)
print(b.shape)
# Out:
# (148, 148)
# (148, 148)
# (148, 148)

# %%
image1[:, :, 1] = 0

# %%
plt.imshow(image1)
plt.axis('off')
# Out:
# (-0.5, 147.5, 147.5, -0.5)

# %%
r
# Out:
# array([[229, 229, 230, ..., 192, 222, 223],
#        [228, 228, 229, ..., 208, 203, 186],
#        [227, 227, 227, ..., 146, 115,  93],
#        ...,
#        [ 95, 100, 104, ..., 111, 117, 122],
#        [ 94,  95,  96, ..., 116, 134, 145],
#        [ 98,  94,  90, ..., 126, 150, 161]], dtype=uint8)

# %%
g
# Out:
# array([[134, 134, 135, ..., 105, 135, 136],
#        [133, 133, 134, ..., 122, 117, 100],
#        [132, 132, 132, ...,  61,  30,   8],
#        ...,
#        [ 19,  30,  43, ...,  33,  39,  44],
#        [ 18,  25,  35, ...,  38,  55,  66],
#        [ 22,  24,  29, ...,  48,  68,  79]], dtype=uint8)

# %%
b
# Out:
# array([[116, 116, 115, ..., 114, 144, 145],
#        [115, 115, 114, ..., 135, 130, 113],
#        [112, 112, 112, ...,  82,  51,  29],
#        ...,
#        [ 58,  66,  74, ...,  57,  63,  66],
#        [ 57,  61,  66, ...,  62,  77,  87],
#        [ 61,  60,  60, ...,  70,  91, 101]], dtype=uint8)

# %%
plt.imshow(r, 'gray')
plt.axis('off')
# Out:
# (-0.5, 147.5, 147.5, -0.5)

# %%
r.max()
# Out:
# 255

# %%
r.min()
# Out:
# 43

# %%
r.mean()
# Out:
# 180.09345325054784

# %%
r<180
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
(r<180).shape
# Out:
# (148, 148)

# %%
r[r<180] = 0

# %%
r[r==0].size
# Out:
# 8805

# %%
148 * 148
# Out:
# 21904

# %%
r[r>=180] = 255

# %%
r[r>=180].size
# Out:
# 13099

# %%
13099+8805
# Out:
# 21904

# %%
plt.imshow(r, 'gray')
plt.axis('off')
plt.show()

# %%
arr = np.random.randint(0, 100, size=(6, 6))

# %%
arr
# Out:
# array([[84, 36, 46, 61, 95, 39],
#        [ 3, 83, 73, 89,  8, 73],
#        [89, 33, 15, 79, 93, 97],
#        [33, 89, 91, 93, 32, 98],
#        [50,  2,  0, 83, 42,  0],
#        [54, 35, 29, 33, 77, 92]])

# %%
arr[0:, 2]
# Out:
# array([46, 73, 15, 91,  0, 29])

# %%
arr[4:, 4:]
# Out:
# array([[42,  0],
#        [77, 92]])

# %%
arr.mean()
# Out:
# 56.361111111111114

# %%
arr > arr.mean()
# Out:
# array([[ True, False, False,  True,  True, False],
#        [False,  True,  True,  True, False,  True],
#        [ True, False, False,  True,  True,  True],
#        [False,  True,  True,  True, False,  True],
#        [False, False, False,  True, False, False],
#        [False, False, False, False,  True,  True]])

# %%
arr[arr > arr.mean()]
# Out:
# array([84, 61, 95, 83, 73, 89, 73, 89, 79, 93, 97, 89, 91, 93, 98, 83, 77,
#        92])

# %%
l = [
    [3, 5],
    [5, 3]
]

# %%
l + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 l + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l
# Out:
# [[3, 5], [5, 3]]

# %%
l2 = [
    [5, 2],
    [5, 2]
]

# %%
l + l2
# Out:
# [[3, 5], [5, 3], [5, 2], [5, 2]]

# %%
arr =  np.array([[2, 4], [3, 5]])

# %%
arr
# Out:
# array([[2, 4],
#        [3, 5]])

# %%
arr + 5
# Out:
# array([[ 7,  9],
#        [ 8, 10]])

# %%
arr
# Out:
# array([[2, 4],
#        [3, 5]])

# %%
arr2 = np.array([2, 3, 5])
arr2
# Out:
# array([2, 3, 5])

# %%
arr + arr2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 arr + arr2
#
# ValueError: operands could not be broadcast together with shapes (2,2) (3,)
