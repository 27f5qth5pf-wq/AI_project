# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rd

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
path = r"C:\Users\HP\Desktop\AI_project\kc_house_data.csv"

# df= pd.read_csv(path,usecols=['sqft_living','price'])

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.iloc[:, 1:].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.iloc[:, 1:].corr()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:13133, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13129         """  # noqa: E501
#   13130         data = self._get_numeric_data() if numeric_only else self
#   13131         cols = data.columns
#   13132         idx = cols.copy()
# > 13133         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13134
#   13135         if method == "pearson":
#   13136             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='str')

# %%
y = df['price']
x = df[['sqft_living' ,  'floors' , 'waterfront' , 'view' , 'condition' , 'grade' , 'sqft_above' , 'sqft_basement' , 'yr_built' , 'yr_renovated' , 'zipcode' , 'lat' , 'long' , 'sqft_living15' , 'sqft_lot15']]

# %%
x.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sqft_living    21613 non-null  int64
#  1   floors         21613 non-null  float64
#  2   waterfront     21613 non-null  int64
#  3   view           21613 non-null  int64
#  4   condition      21613 non-null  int64
#  5   grade          21613 non-null  int64
#  6   sqft_above     21613 non-null  int64
#  7   sqft_basement  21613 non-null  int64
#  8   yr_built       21613 non-null  int64
#  9   yr_renovated   21613 non-null  int64
#  10  zipcode        21613 non-null  int64
#  11  lat            21613 non-null  float64
#  12  long           21613 non-null  float64
#  13  sqft_living15  21613 non-null  int64
#  14  sqft_lot15     21613 non-null  int64
# dtypes: float64(3), int64(12)
# memory usage: 2.5 MB

# %%
x.shape
# Out:
# (21613, 15)

# %%
y.shape
# Out:
# (21613,)

# %%
x.loc[:, 'sqft_living'])

# %%
for col in  x.columns:
    x[col] = x.[col].astype(float)
    x[col] = x[col]/x[col].max()
# Out:
#   Cell In[76], line 2
#     x[col] = x.[col].astype(float)
#                ^
# SyntaxError: invalid syntax

# %%
x
# Out:
#        sqft_living    floors  waterfront  view  condition     grade  \
# 0         0.087149  0.285714         0.0   0.0        0.6  0.538462
# 1         0.189808  0.571429         0.0   0.0        0.6  0.538462
# 2         0.056869  0.285714         0.0   0.0        0.6  0.461538
# 3         0.144756  0.285714         0.0   0.0        1.0  0.538462
# 4         0.124077  0.285714         0.0   0.0        0.6  0.615385
# ...            ...       ...         ...   ...        ...       ...
# 21608     0.112999  0.857143         0.0   0.0        0.6  0.615385
# 21609     0.170606  0.571429         0.0   0.0        0.6  0.615385
# 21610     0.075332  0.571429         0.0   0.0        0.6  0.538462
# 21611     0.118168  0.571429         0.0   0.0        0.6  0.615385
# 21612     0.075332  0.571429         0.0   0.0        0.6  0.538462
#
#        sqft_above  sqft_basement  yr_built  yr_renovated   zipcode       lat  \
# ...
