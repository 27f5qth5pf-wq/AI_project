# %% [markdown]
# ## OOPs

# %%
class Car:
    def __init__(self, name, color, model):
        self.name = name
        self.color = color
        self.model = model

# %%
car1 = Car("Honda Civic", "Black", 2025)

# %%
print(car1)

# %%
print(car1.name)
# Out:
# Honda Civic

# %%
print(car1.model)
# Out:
# 2025

# %%
print(car1.color)
# Out:
# Black

# %%
car1.model = 2026

# %%
car1.model
# Out:
# 2026

# %%
## object 2

car2 = Car("Mercides", "black", 1980)

# %%
print(car1)
print(car2)

# %%
print(car2.name)
# Out:
# Mercides

# %%
print(car2.color)
# Out:
# black

# %%
class Car:
    def __init__(self, name, color, model):
        print(id(self))
        self.name = name
        self.color = color
        self.model = model

# %%
Car1 = Car("BMW", "White", 2020)
Car2 = Car("Suzuki", "White", 2026)
# Out:
# 1985580174224
# 1985585970896

# %%
print(id(Car1))
print(id(Car2))
# Out:
# 1985580174224
# 1985585970896

# %%
Car1.name
# Out:
# 'BMW'

# %%
## class with function/methods

# %%
class Car:
    def __init__(self, name, color, model):
        self.name = name
        self.color = color
        self.model = model

    def show_details(self):
        print(id(self))
        print("-------Car Details------")
        print("Name : ", self.name)
        print("Color : ", self.color)
        print("Model : ", self.model)

# %%
car = Car("Honda", "Black", 2018)

# %%
car.name
# Out:
# 'Honda'

# %%
print(id(car))
# Out:
# 1985580107088

# %%
car.show_details()
# Out:
# 1985580107088
# -------Car Details------
# Name :  Honda
# Color :  Black
# Model :  2018

# %%
Car.show_details(car)
# Out:
# 1985580107088
# -------Car Details------
# Name :  Honda
# Color :  Black
# Model :  2018

# %%
### Account

# %%
class Account:
    def __init__(self, acc_no, acc_holder, acc_balance, is_active):
        self.account_number = acc_no
        self.account_holder = acc_holder
        self.account_balance = acc_balance
        self.is_active = is_active

    def deposit(self):
        print("Deposit")
    
    def transfor(self):
        print("transfor")

    def withdraw(self):
        print("withdraw")

    def check_balance(self):
        print("check balance")

# %%
acc1 = Account("23892324", "Talha", 20000000, True)

# %%
print(acc1.account_holder)
# Out:
# Talha

# %%
print(acc1.account_balance)
# Out:
# 20000000

# %%
acc1.deposit()
# Out:
# Deposit

# %%
acc1.withdraw()
# Out:
# withdraw

# %%
class Account:
    def __init__(self, acc_no, acc_holder, acc_balance, is_active):
        self.account_number = acc_no
        self.account_holder = acc_holder
        self.account_balance = acc_balance
        self.is_active = is_active

    def deposit(self, amount):
        if amount > 50000:
            print("Daily Deposit limit is Rs.50000")
        elif amount < 0:
            print("Amount must be positive")
        else:
            self.account_balance += amount
    
    def transfor(self):
        print("transfor")

    def withdraw(self):
        print("withdraw")

    def check_balance(self):
        print("check balance")

# %%
acc1 = Account("23892324", "Talha", 200000, True)

# %%
acc1.deposit(20000)

# %%
acc1.account_balance
# Out:
# 240000

# %%
acc1.deposit(60000)
# Out:
# Daily Deposit limit is Rs.50000

# %%
acc1.deposit(-100)
# Out:
# Amount must be positive

# %%
class Account:
    def __init__(self, acc_no, acc_holder, acc_balance, is_active):
        self.account_number = acc_no
        self.account_holder = acc_holder
        self.account_balance = acc_balance
        self.is_active = is_active

    def deposit(self, amount):
        if amount > 50000:
            print("Daily Deposit limit is Rs.50000")
        elif amount <= 0:
            print("Amount must be positive")
        else:
            self.account_balance += amount
            print("Deposit Successful")
            print(f"Your new balance is : {self.account_balance}")
    
    def transfor(self, receiver_acc_no, amount):
        if amount <= 0:
            print("Transfor Amount must be positive")
        elif amount >= self.account_balance:
            print(f"Your current balance is : {self.account_balance}")
        elif amount > 50000:
            print("Your daily transfor limit is RS.50000")
        else:
            self.account_balance -= amount
            print("Transfor successful")
            print(f"An amount of {amount} is transfored to {receiver_acc_no} account number")
            print(f"You current balance is now : {self.account_balance}")
        

    def withdraw(self):
        print("withdraw")

    def check_balance(self):
        print("check balance")

# %%
acc1 = Account("23892324", "Talha", 200000, True)

# %%
acc1.transfor("4282903892", 2000)
# Out:
# Transfor successful
# An amount of 2000 is transfored to 4282903892 account number
# You current balance is now : 198000

# %%
acc1.transfor("2489238992", -100)
# Out:
# Transfor Amount must be positive

# %%
acc1.transfor("4289032839", 50001)
# Out:
# Your daily transfor limit is RS.50000

# %%
acc1.transfor("382922389", 250000)
# Out:
# Your current balance is : 198000

# %%
acc1.transfor("38928329", 60000)
# Out:
# Your daily transfor limit is RS.50000

# %%
class Account:
    def __init__(self, acc_no, acc_holder, acc_balance, is_active):
        self.account_number = acc_no
        self.account_holder = acc_holder
        self.account_balance = acc_balance
        self.is_active = is_active

    def deposit(self, amount):
        if amount > 50000:
            print("Daily Deposit limit is Rs.50000")
        elif amount <= 0:
            print("Amount must be positive")
        else:
            self.account_balance += amount
            print("Deposit Successful")
            print(f"Your new balance is : {self.account_balance}")
    
    def transfor(self, receiver_acc_no, amount):
        if amount <= 0:
            print("Transfor Amount must be positive")
        elif amount >= self.account_balance:
            print(f"Your current balance is : {self.account_balance}")
        elif amount > 50000:
            print("Your daily transfor limit is RS.50000")
        else:
            self.account_balance -= amount
            print("Transfor successful")
            print(f"An amount of {amount} is transfored to {receiver_acc_no} account number")
            print(f"You current balance is now : {self.account_balance}")
        

    def withdraw(self, amount):
        if amount <= 0:
            print("Are you mad how can hou withdraw nigative amount")
        elif amount > self.account_balance:
            print("Ja moh do k awo")
        elif amount > 50000:
            print("Your account is not a premium account")
        else:
            self.account_balance -= amount
            print(f"An amount of {amount} has been withdraw from your account")

    def check_balance(self):
        print("check balance")

# %%
acc1 = Account("382938892", "Ali", 100000, True)

# %%
acc1.withdraw(20000)
# Out:
# An amount of 20000 has been withdraw from your account

# %%
acc1.withdraw(-100)
# Out:
# Are you mad how can hou withdraw nigative amount

# %%
acc1.withdraw(55000)
# Out:
# Your account is not a premium account

# %%
acc1.account_balance
# Out:
# 80000

# %%
acc1.withdraw(100000)
# Out:
# Ja moh do k awo

# %%
class Account:
    def __init__(self, acc_no, acc_holder, acc_balance, is_active):
        self.account_number = acc_no
        self.account_holder = acc_holder
        self.account_balance = acc_balance
        self.is_active = is_active

    def deposit(self, amount):
        if amount > 50000:
            print("Daily Deposit limit is Rs.50000")
        elif amount <= 0:
            print("Amount must be positive")
        else:
            self.account_balance += amount
            print("Deposit Successful")
            print(f"Your new balance is : {self.account_balance}")
    
    def transfor(self, receiver_account, amount):
        if amount <= 0:
            print("Transfor Amount must be positive")
        elif amount >= self.account_balance:
            print(f"Your current balance is : {self.account_balance}")
        elif amount > 50000:
            print("Your daily transfor limit is RS.50000")
        else:
            self.account_balance -= amount
            receiver_account.account_balance += amount
            print("Transfor successful")
            print(f"An amount of {amount} is transfored to {receiver_account.account_holder}")
            print(f"You new balance is : {self.account_balance}")
        

    def withdraw(self, amount):
        if amount <= 0:
            print("Are you mad how can hou withdraw nigative amount")
        elif amount > self.account_balance:
            print("Ja moh do k awo")
        elif amount > 50000:
            print("Your account is not a premium account")
        else:
            self.account_balance -= amount
            print(f"An amount of {amount} has been withdraw from your account")

    def check_balance(self):
        print("check balance")

# %%
acc1 = Account("39898393", "Ahmad", 200000, True)
acc2 = Account("78979882", "Ali", 100000, True)

# %%
acc1.transfor(acc2, 30000)
# Out:
# Transfor successful
# An amount of 30000 is transfored to Ali
# You new balance is : 170000

# %%
acc2.account_balance
# Out:
# 130000

# %%
acc1.account_balance
# Out:
# 170000
