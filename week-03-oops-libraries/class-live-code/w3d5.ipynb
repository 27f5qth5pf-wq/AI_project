# %%
text = r "The duration of your domain registration can vary depending on the domain extension you purchase. With most extensions, domain name registrars allow customers to register domains for up to 10 years at a time. Typically, customers register domains for one to three years. Some premium domains and gTLDs (like .au and .nl) have shorter registration periods."

# %%
with open('files/excercise.txt', 'w') as f:
    f.writelines("Hi \n")
