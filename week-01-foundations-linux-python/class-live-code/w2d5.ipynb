# %% [markdown]
# ### Function

# %%
def greet ():
    print("well come to Ai course ")

# %%
greet()
# Out:
# well come to Ai course

# %%
def greet (name):
    print(f"well come to Ai course  {name}")

# %%
greet("admin")
# Out:
# well come to Ai course  admin

# %%
def add (num1, num2):
    add = num1 + num2 
    return add

# %%
add(12,12)
# Out:
# 24

# %%
# Out:
# '12 X 0 = 0'

# %%
def calulator ():
    num1 =int (input("Enter  first number : "))
    num2 =int (input("Enter  second number : "))
    op = input("Enter , + , - , / ")
    result = 0

    if op == '+':
        result  = num1 + num2
    elif op == '-':
        result  = num1 - num2
    elif op == '*':
        result  = num1 * num2
    elif op == '/':
        if num2 == 0:
            print (f"{num1}divition not devide by zero")
        else:
            result  = num1 / num2
    else:
        print("plesce enter opertor (+,-,*,/) supported")
        return
    print(f'result {result}')

# %%
count = 0
while count < 4:

    calulator()
    count+=1
# Out:
# plesce enter opertor (+,-,*,/) supported

# %%
def pattern(r,c):
    for i in range(r):
        for j in range(c):
            print("*" , end=" ")

        print()
pattern(5,10)
# Out:
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *

# %%
def pattern_2(num):
    for i in range (num):
        for j in range (i):
            print("*", end=" ")
        print ()
    
    for i in range (num,0,-1):
        for j in range (i):
            print("*", end=" ")
        print ()
pattern_2(5)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
print ("qwq",122,122.12)
# Out:
# qwq 122 122.12
