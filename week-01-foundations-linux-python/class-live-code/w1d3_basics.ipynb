# %%
print("hello world")
# Out:
# hello world

# %%
print(4372)
# Out:
# 4372

# %%
print(4.3)
# Out:
# 4.3

# %%
print(True)
# Out:
# True

# %%
print("salamna", 'kamran', 'asim')
# Out:
# salamna kamran asim

# %%
print("Name : ", "asim", "age : ", 20)
# Out:
# Name :  asim age :  20

# %%
print("Salman", "Khan")
# Out:
# Salman Khan

# %%
print("salman", 'khan', sep="")
# Out:
# salmankhan

# %%
print("salman", 'khan', sep="***")
# Out:
# salman***khan

# %%
print("salman", 'khan', 'actor', sep="*")
# Out:
# salman*khan*actor

# %%
print("first line")
print("second line")
# Out:
# first line
# second line

# %%
print("first line", end='----')
print("second line")
# Out:
# first line----second line

# %%
print("apple", 'mango', 'banana', sep='|', end='    ')
print("apple", 'mango', 'banana', sep='|', end='    ')
print("apple", 'mango', 'banana', sep='|')
# Out:
# apple|mango|banana    apple|mango|banana    apple|mango|banana

# %%
print("first line\nsecond line")
# Out:
# first line
# second line

# %%
print("first line\n\nsecond line")
# Out:
# first line
#
# second line

# %%
# escape sequences 
# \t

# %%
print("muhammad\tsalman")
# Out:
# muhammad	salman

# %%
# \b

print("khan\b")
# Out:
# kha

# %%
## \r

print("Tauqeer\rahmad")
# Out:
# ahmader

# %%
print("\"be the change you wanna see in the world\"")
# Out:
# "be the change you wanna see in the world"

# %%
print('"Be the change you wanna se in the world"')
# Out:
# "Be the change you wanna se in the world"

# %%
path = "D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Advance-Python-Programming-and-Application-NAVTTC-Course-2026\Week-01\notebooks"

# %%
print(path)
# Out:
# D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Advance-Python-Programming-and-Application-NAVTTC-Course-2026\Week-01
# otebooks

# %%
path = r"D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Advance-Python-Programming-and-Application-NAVTTC-Course-2026\Week-01\notebooks"

# %%
print(path)
# Out:
# D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Advance-Python-Programming-and-Application-NAVTTC-Course-2026\Week-01\notebooks

# %%
print("umar"+"akmal"+"cricketer")
# Out:
# umarakmalcricketer

# %%
print(10+20+30)
# Out:
# 60

# %%
print("string"+"43")
# Out:
# string43

# %%
print("i am ", "ahmad", "and i am ", 23, "year old")
# Out:
# i am  ahmad and i am  23 year old

# %%
print("i am ahamd and i am 23 year old")
# Out:
# i am ahamd and i am 23 year old

# %%
name = 'ahmad'
age = 23

print("i am ", name, "and i am", age, "year old")
# Out:
# i am  ahmad and i am 23 year old

# %%
print(f"i am {name} and i am {age} year old")
# Out:
# i am ahmad and i am 23 year old

# %%
print("i am {} and i am {} year old".format(name, age))
# Out:
# i am ahmad and i am 23 year old

# %%
print("i am {} and i am {} year old".format(age, name))
# Out:
# i am 23 and i am ahmad year old

# %%
print("i am {1} and i am {0} year old".format(age, name))
# Out:
# i am ahmad and i am 23 year old

# %%
## variables and data types

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Variable and data types

# %%
student_name = 'ali'

# %%
print(student_name)
# Out:
# ali

# %%
print("Name : ", student_name)
# Out:
# Name :  ali

# %%
temperature = 45.9

# %%
print(temperature)
# Out:
# 45.9

# %%
bank_balance = 120000

# %%
print(bank_balance)
# Out:
# 120000

# %%
is_pass = False

# %%
is_pass
# Out:
# False

# %%
temperature
# Out:
# 45.9

# %%
temperature
bank_balance
# Out:
# 120000

# %%
a = 1000
b = 2000

# %%
print(a + b)
# Out:
# 3000

# %%
add = a + b

# %%
print(add)
# Out:
# 3000

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(temperature)
# Out:
# float

# %%
type(student_name)
# Out:
# str

# %%
type(is_pass)
# Out:
# bool

# %%
print(a - b)
# Out:
# -1000

# %%
sub = a - b

# %%
print(sub)
# Out:
# -1000

# %%
print(a * b)
# Out:
# 2000000

# %%
mul = a * b

# %%
print(mul)
# Out:
# 2000000

# %%
type(mul)
# Out:
# int

# %%
print(b/a)
# Out:
# 2.0

# %%
d = b/a

# %%
type(d)
# Out:
# float

# %%
a = 24
b = 4

floor_div = a//b

# %%
print(floor_div)
# Out:
# 6

# %%
a = 26
b = 4

floor_div = a//b

# %%
a/b
# Out:
# 6.5

# %%
a = 26
b = 4

floor_div = a//b

print(floor_div)
# Out:
# 6

# %%
## modulas

# %%
a
# Out:
# 26

# %%
b
# Out:
# 4

# %%
## % 

print(a%b)
# Out:
# 2

# %%
## power

# %%
2**8
# Out:
# 256

# %%
a
# Out:
# 26

# %%
b
# Out:
# 4

# %%
a**b
# Out:
# 456976

# %%
26 * 26 * 26 * 26
# Out:
# 456976

# %%
large_number = 199999999999999999999999999999999

# %%
large_number
# Out:
# 199999999999999999999999999999999

# %% [markdown]
# ## Float

# %%
height = 5.6

# %%
type(height)
# Out:
# float

# %%
l = 6.7
w = 9.0

# %%
print(l * w)
print(l + w)
print(l - w)
print(l / w)
print(l // w)
print(l ** w)
print(l % w)
# Out:
# 60.300000000000004
# 15.7
# -2.3
# 0.7444444444444445
# 0.0
# 27206534.396294955
# 6.7

# %% [markdown]
# ## string date type

# %%
name = "muahammad salman"

# %%
print(name)
# Out:
# muahammad salman

# %%
type(name)
# Out:
# str

# %%
name = 'muhammad samlan'

# %%
type(name)
# Out:
# str

# %%
text = """od exhibits a substantial performance advantage. Further
more, we surpass the historically promising SCH6 approach,
which employs a resource-intensive hybrid, late fusion scheme,
offering a more cost-effective solution."""

# %%
print(text)
# Out:
# od exhibits a substantial performance advantage. Further
# more, we surpass the historically promising SCH6 approach,
# which employs a resource-intensive hybrid, late fusion scheme,
# offering a more cost-effective solution.

# %%
first_name = 'kamran'
last_name = 'akmal'

# %%
first_name + last_name
# Out:
# 'kamranakmal'

# %%
first_name + " " + last_name
# Out:
# 'kamran akmal'

# %%
full_name = first_name + " " + last_name

# %%
print(full_name)
# Out:
# kamran akmal

# %%
"Ha" * 5
# Out:
# 'HaHaHaHaHa'

# %%
"Ha" * "Ha"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 "Ha" * "Ha"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
text
# Out:
# 'od exhibits a substantial performance advantage. Further\nmore, we surpass the historically promising SCH6 approach,\nwhich employs a resource-intensive hybrid, late fusion scheme,\noffering a more cost-effective solution.'

# %%
print(text.upper())
# Out:
# OD EXHIBITS A SUBSTANTIAL PERFORMANCE ADVANTAGE. FURTHER
# MORE, WE SURPASS THE HISTORICALLY PROMISING SCH6 APPROACH,
# WHICH EMPLOYS A RESOURCE-INTENSIVE HYBRID, LATE FUSION SCHEME,
# OFFERING A MORE COST-EFFECTIVE SOLUTION.

# %%
full_name
# Out:
# 'kamran akmal'

# %%
full_name.upper()
# Out:
# 'KAMRAN AKMAL'

# %%
"NAME".lower()
# Out:
# 'name'

# %%
text_upper = text.upper()

# %%
print(text_upper)
# Out:
# OD EXHIBITS A SUBSTANTIAL PERFORMANCE ADVANTAGE. FURTHER
# MORE, WE SURPASS THE HISTORICALLY PROMISING SCH6 APPROACH,
# WHICH EMPLOYS A RESOURCE-INTENSIVE HYBRID, LATE FUSION SCHEME,
# OFFERING A MORE COST-EFFECTIVE SOLUTION.

# %%
print(text_upper.lower())
# Out:
# od exhibits a substantial performance advantage. further
# more, we surpass the historically promising sch6 approach,
# which employs a resource-intensive hybrid, late fusion scheme,
# offering a more cost-effective solution.

# %%
print(text.capitalize())
# Out:
# Od exhibits a substantial performance advantage. further
# more, we surpass the historically promising sch6 approach,
# which employs a resource-intensive hybrid, late fusion scheme,
# offering a more cost-effective solution.

# %%
full_name.capitalize()
# Out:
# 'Kamran akmal'

# %%
full_name.title()
# Out:
# 'Kamran Akmal'

# %%
print(text.title())
# Out:
# Od Exhibits A Substantial Performance Advantage. Further
# More, We Surpass The Historically Promising Sch6 Approach,
# Which Employs A Resource-Intensive Hybrid, Late Fusion Scheme,
# Offering A More Cost-Effective Solution.

# %%
full_name
# Out:
# 'kamran akmal'

# %%
full_name.split()
# Out:
# ['kamran', 'akmal']

# %%
text.split()
# Out:
# ['od',
#  'exhibits',
#  'a',
#  'substantial',
#  'performance',
#  'advantage.',
#  'Further',
#  'more,',
#  'we',
#  'surpass',
#  'the',
#  'historically',
#  'promising',
#  'SCH6',
#  'approach,',
#  'which',
#  'employs',
#  'a',
#  'resource-intensive',
#  'hybrid,',
#  'late',
#  'fusion',
#  'scheme,',
#  'offering',
#  'a',
#  'more',
#  'cost-effective',
#  'solution.']

# %%
full_name = "  muhammad moiz    "

# %%
print(full_name)
# Out:
#   muhammad moiz

# %%
print(full_name.strip())
# Out:
# muhammad moiz

# %%
full_name.lstrip()
# Out:
# 'muhammad moiz    '

# %%
full_name.rstrip()
# Out:
# '  muhammad moiz'

# %%
full_name.strip()
# Out:
# 'muhammad moiz'

# %%
full_name
# Out:
# '  muhammad moiz    '

# %%
full_name = full_name.strip()

# %%
is_pass = True

# %%
type(is_pass)
# Out:
# bool

# %%
is_pass = False

# %%
type(is_pass)
# Out:
# bool

# %%
print(is_pass)
# Out:
# False

# %%
a
# Out:
# 26

# %%
b
# Out:
# 4

# %%
float(a)
# Out:
# 26.0

# %%
float(b)
# Out:
# 4.0

# %%
float(full_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 float(full_name)
#
# ValueError: could not convert string to float: '  muhammad moiz    '

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
temperature
# Out:
# 45.9

# %%
int(temperature)
# Out:
# 45

# %%
temp = int(temperature)

# %%
temp
# Out:
# 45

# %%
type(temp)
# Out:
# int

# %%
int("abb")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 int("abb")
#
# ValueError: invalid literal for int() with base 10: 'abb'

# %%
int("43a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 int("43a")
#
# ValueError: invalid literal for int() with base 10: '43a'

# %%
float("43.5")
# Out:
# 43.5

# %%
str(a)
# Out:
# '26'

# %%
str(temperature)
# Out:
# '45.9'

# %%
str(True)
# Out:
# 'True'

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(0.0000001)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool('a')
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
name = "khalid"

name.upper()
# Out:
# 'KHALID'

# %%
print(name)
# Out:
# khalid

# %%
name = "khalid"

print(name.upper())

# %%
name.title()
# Out:
# 'Khalid'

# %%
name.capitalize()
# Out:
# 'Khalid'

# %%
name.lower()
# Out:
# 'khalid'

# %%
text = "  the 4th day of ai journay   "

text.strip()
# Out:
# 'the 4th day of ai journay'

# %%
text
# Out:
# '  the 4th day of ai journay   '

# %%
text.lstrip()
# Out:
# 'the 4th day of ai journay   '

# %%
text.rstrip()
# Out:
# '  the 4th day of ai journay'

# %%
text
# Out:
# '  the 4th day of ai journay   '

# %%
text = text.strip()

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text.split()
# Out:
# ['the', '4th', 'day', 'of', 'ai', 'journay']

# %%
text2 = "further,understand,the,performance,of,our,proposed,architecture"

# %%
text2.split()
# Out:
# ['further,understand,the,performance,of,our,proposed,architecture']

# %%
text2.split(",")
# Out:
# ['further',
#  'understand',
#  'the',
#  'performance',
#  'of',
#  'our',
#  'proposed',
#  'architecture']

# %%
fruits = ['mango', 'orange', 'banana', 'apple']

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
".".join(fruits)
# Out:
# 'mango.orange.banana.apple'

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text2
# Out:
# 'further,understand,the,performance,of,our,proposed,architecture'

# %%
text.count("a")
# Out:
# 3

# %%
paper = """Generalization Performance Analysis: To evaluate the gen
eralizability of the proposed model, we conduct an assessment
of MSE-GCN using the test set sampled from MS-ASL [42],
which is a large-scale, signer-independent ASL dataset. The
model, trained on the WLASL-100 training set, is tested using
samples from the MS-ASL dataset that correspond to classes
present in the WLASL-100 subset. To ensure a comprehensive
evaluation, we include at least three samples per class"""

# %%
print(paper)
# Out:
# Generalization Performance Analysis: To evaluate the gen
# eralizability of the proposed model, we conduct an assessment
# of MSE-GCN using the test set sampled from MS-ASL [42],
# which is a large-scale, signer-independent ASL dataset. The
# model, trained on the WLASL-100 training set, is tested using
# samples from the MS-ASL dataset that correspond to classes
# present in the WLASL-100 subset. To ensure a comprehensive
# evaluation, we include at least three samples per class

# %%
paper
# Out:
# 'Generalization Performance Analysis: To evaluate the gen\neralizability of the proposed model, we conduct an assessment\nof MSE-GCN using the test set sampled from MS-ASL [42],\nwhich is a large-scale, signer-independent ASL dataset. The\nmodel, trained on the WLASL-100 training set, is tested using\nsamples from the MS-ASL dataset that correspond to classes\npresent in the WLASL-100 subset. To ensure a comprehensive\nevaluation, we include at least three samples per class'

# %%
paper.count("large-scale")
# Out:
# 1

# %%
paper.find("large-scale")
# Out:
# 186

# %% [markdown]
# ## find funtion
# ## index function

# %% [markdown]
# # Indexing and slicing

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
len(fruits)
# Out:
# 4

# %%
fruits[0]
# Out:
# 'mango'

# %%
fruits[3]
# Out:
# 'apple'

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text[7]
# Out:
# ' '

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 fruits[4]
#
# IndexError: list index out of range

# %%
fruits[-1]
# Out:
# 'apple'

# %%
fruits[-2]
# Out:
# 'banana'

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text[-1]
# Out:
# 'y'

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[0:2:1]
# Out:
# ['mango', 'orange']

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text[0:10:2]
# Out:
# 'te4hd'

# %%
fruits
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[0:]
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[2:]
# Out:
# ['banana', 'apple']

# %%
fruits[::]
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[0:4]
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[0:10]
# Out:
# ['mango', 'orange', 'banana', 'apple']

# %%
fruits[-1:-5:-1]
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
fruits[::-1]
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text.find('a')
# Out:
# 9

# %%
text.index('a')
# Out:
# 9

# %%
text.find('ai')
# Out:
# 15

# %%
text
# Out:
# 'the 4th day of ai journay'

# %%
text.find("apple")
# Out:
# -1

# %%
text.index("apple")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 text.index("apple")
#
# ValueError: substring not found

# %%
pi = 3.1415694

# %%
print(f"PI : {pi:.1f}")
# Out:
# PI : 3.1

# %%
print(pi:.2f)
# Out:
#   Cell In[77], line 1
#     print(pi:.2f)
#               ^
# SyntaxError: invalid decimal literal

# %%
age = input("Enter your age : ")

print(age)
# Out:
# 56

# %%
num1 = input("enter first number : ")
num1 = int(num1)
num2 = input("enter second number : ")
num2 = int(num2)

print("Addition of num1 and num2 = ", num1+num2 )
# Out:
# Addition of num1 and num2 =  70

# %%
num1 = int(input("enter first number : "))
num2 = int(input("enter second number : "))

print(f"Addition of {num1} and {num2} = ", num1+num2 )
# Out:
# Addition of 20 and 30 =  50
