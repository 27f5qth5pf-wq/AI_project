# %% [markdown]
# ## assignment operators

# %%
age = 10

# %%
age
# Out:
# 10

# %%
age += 5       # age = age + 5

# %%
print(age)
# Out:
# 15

# %%
age -= 5

# %%
age
# Out:
# 10

# %%
age *= 4

# %%
age
# Out:
# 40

# %%
age /= 10

# %%
age
# Out:
# 4.0

# %%
price = 500

# %%
type(price)
# Out:
# int

# %%
price/100 * 20
# Out:
# 100.0

# %%
price = 500

# %%
price **= 3   # price = price ** 3

# %%
price
# Out:
# 125000000

# %%
price * price * price
# Out:
# 1953125000000000000000000

# %%
price
# Out:
# 125000000

# %% [markdown]
# ## identity operators

# %%
## is

a = 50
b = 30

a is b
# Out:
# False

# %%
id(a)
# Out:
# 140717415913800

# %%
id(b)
# Out:
# 140717415913160

# %%
b = a

# %%
a
# Out:
# 50

# %%
b
# Out:
# 50

# %%
id(a)
# Out:
# 140717415913800

# %%
id(b)
# Out:
# 140717415913800

# %%
a is b
# Out:
# True

# %%
b = b+10

# %%
b
# Out:
# 60

# %%
a
# Out:
# 50

# %%
id(a)
# Out:
# 140717415913800

# %%
id(b)
# Out:
# 140717415914120

# %%
price1 = 15
price2 = 15

# %%
print("Price 1 ID", id(price1))
print("Price 1 ID", id(price2))
# Out:
# Price 1 ID 140717415912680
# Price 1 ID 140717415912680

# %%
price1 = 15000
price2 = 15000

# %%
id(price1)
# Out:
# 2202452391728

# %%
id(price2)
# Out:
# 2202452393808

# %%
price1 is price2
# Out:
# False

# %%
price1 == price2
# Out:
# True

# %%
## is not

price1 is not price2
# Out:
# True

# %% [markdown]
# ## logical operators

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and Fasle
# Out:
# False

# %%
correct_name = "ahmad"
current_name = "Ahmad"

# %%
correct_name == current_name
# Out:
# False

# %%
bool(correct_name)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
user = input("Enter username : ")
password = input("Enter password : ")

print("Both username and passowrd contain at least one chaaracter : ", bool(user) and bool(password))
# Out:
# Both username and passowrd contain at least one chaaracter :  False

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
marks1 = 80
marks2 = 70
marks3 = 60

marks1 > marks2 and marks3 > marks1
# Out:
# False

# %%
marks1 = 80
marks2 = 70
marks3 = 60

marks1 > marks2 or marks3 > marks1
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not bool("")
# Out:
# True

# %%
not bool(0.0)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
not marks1 > marks2 or marks3 > marks1
# Out:
# False

# %%
False or False
# Out:
# False

# %% [markdown]
# ## Bitwise Operators

# %%
## &

True & True
# Out:
# True

# %%
False & True
# Out:
# False

# %%
True & False
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | False
# Out:
# False

# %%
True ^ True
# Out:
# False

# %%
False ^ True
# Out:
# True

# %%
True ^ False
# Out:
# True

# %%
False ^ False
# Out:
# False

# %%
~ True
# Out:
# -2

# %%
6 & 5
# Out:
# 4

# %%
5 & 2
# Out:
# 0

# %%
13 | 15
# Out:
# 15

# %%
fn = input("enter first name : ")
ln = input("enter last name : ")


print(fn)
print(ln)

print(len(fn))
print(len(ln))

rfn = fn[-1:-len(fn)-1:-1]
rln = ln[-1:-len(ln)-1:-1]

print(rfn)
print(rln)
# Out:
# muhammad
# kamil
# 8
# 5
# dammahum
# limak
