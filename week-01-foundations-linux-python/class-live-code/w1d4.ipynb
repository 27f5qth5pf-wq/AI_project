# %%
student1_marks = 80
student2_marks = 60

# %%
print(student1_marks == student2_marks)
# Out:
# False

# %%
print(student1_marks != student2_marks)
# Out:
# True

# %%
print(student1_marks > student2_marks)
# Out:
# True

# %%
print(student1_marks < student2_marks)
# Out:
# False

# %%
student1_marks = 60

# %%
print(student1_marks)
print(student2_marks)
# Out:
# 60
# 60

# %%
print(student1_marks <= student2_marks)
# Out:
# True

# %%
name1 = 'ali'
name2 = "m ali"

name1 == name2
# Out:
# False

# %%
name1 != name2
# Out:
# True

# %%
name1 = name2

# %%
name1
# Out:
# 'm ali'

# %%
num1 = 20

# %%
+num1
# Out:
# 20

# %%
a = 10
b = 10
c = 30

a == b == c
# Out:
# False

# %%
c > b <= a
# Out:
# True

# %%
students = ["talha", 'tauqeer', 'shakoor', 'hamza', 'hassan', 'ilyas', 'javad']

# %%
len(students)
# Out:
# 7

# %%
"abbas" in students
# Out:
# False

# %%
students in "ilyas"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 students in "ilyas"
#
# TypeError: 'in <string>' requires string as left operand, not list

# %%
"ilyas" not in students
# Out:
# False

# %%
text = "Be the change you wanna see in the world"

# %%
"the" in text
# Out:
# True

# %%
"the" not in text
# Out:
# False
