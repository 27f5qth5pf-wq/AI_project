# %% [markdown]
# #

# %%
student = {
    "name" : "shakoor",
    "age" : 20,
    "semester" : 3,
    "sub" : ['python','java','c++'],
    "marks" : [30,40,50],
    
}

# %%
print('Name : ',student['name'])
print('age : ',student['age'])
print('semestrr : ',student['semester'])
print('sub : ',student['sub'])
print('marks ',student['marks'])
# Out:
# Name :  shakoor
# age :  20
# semestrr :  3
# sub :  ['python', 'java', 'c++']
# marks  [30, 40, 50]
# mgpa  3.5

# %%
student.update({'gpa':3.5})

# %%
student
# Out:
# {'name': 'shakoor',
#  'age': 20,
#  'semester': 3,
#  'sub': ['python', 'java', 'c++'],
#  'marks': [30, 40, 50],
#  'gpa': 3.5}

# %%
student.pop('age')
# Out:
# 20

# %%
student.popitem()
# Out:
# ('gpa', 3.5)

# %%
student.keys()
# Out:
# dict_keys(['name', 'semester', 'sub', 'marks'])

# %%
student.values()
# Out:
# dict_values(['shakoor', 3, ['python', 'java', 'c++'], [30, 40, 50]])

# %%
student.items()
# Out:
# dict_items([('name', 'shakoor'), ('semester', 3), ('sub', ['python', 'java', 'c++']), ('marks', [30, 40, 50])])

# %%
student.clear()

# %%
id(student)
# Out:
# 1156618237184

# %%
student.get('age')
# Out:
# 20

# %%
student.get("ajsdn")

# %%
print(student.setdefault('age', 21))
# Out:
# 20

# %%
print(student)
# Out:
# {'name': 'shakoor', 'age': 20, 'semester': 3, 'sub': ['python', 'java', 'c++'], 'marks': [30, 40, 50]}

# %% [markdown]
# # Tuple

# %% [markdown]
# # Set

# %%
import math
