# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.read_csv(r"C:\Users\HP\Desktop\AI_project\week-05-visualization-first-models-and-ML\datasets\ex2x.dat")
y = pd.read_csv (r"C:\Users\HP\Desktop\AI_project\week-05-visualization-first-models-and-ML\datasets\ex2y.dat")

# %%
x
# Out:
#     2.0658746e+00
# 0        2.368409
# 1        2.539993
# 2        2.542080
# 3        2.549079
# 4        2.786688
# 5        2.911682
# 6        3.035627
# 7        3.114670
# 8        3.158239
# 9        3.327594
# 10       3.379316
# 11       3.412201
# 12       3.421582
# 13       3.531573
# 14       3.639300
# 15       3.673254
# 16       3.925646
# 17       4.049865
# 18       4.248335
# 19       4.344005
# 20       4.382653
# 21       4.423060
# 22       4.610244
# 23       4.688118
# 24       4.977733
# 25       5.035997
# 26       5.068454
# 27       5.416149
# 28       5.439562
# 29       5.456321
# 30       5.569846
# 31       5.601573
# 32       5.687762
# 33       5.721560
# 34       5.853891
# 35       6.197803
# 36       6.351094
# 37       6.479703
# 38       6.738379
# 39       6.863769
# 40       7.022339
# 41       7.078237
# 42       7.151423
# 43       7.466402
# 44       7.597387
# 45       7.744072
# 46       7.772966
# 47       7.826451
# 48       7.930636

# %%
x.shape
# Out:
# (49, 1)

# %%
y.shape
# Out:
# (49, 1)
